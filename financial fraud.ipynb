# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
import os
os.getcwd()
# Out:
# '/Users/pawanrana'

# %%
os.listdir()
# Out:
# ['.zshrc.save',
#  '.eclipse',
#  '.config',
#  'Music',
#  'tfidf_vectorizer.pkl',
#  'Untitled1.ipynb',
#  'fake_news_model.pkl',
#  '.DS_Store',
#  'eclipse',
#  'Anmol',
#  'pawan',
#  '.CFUserTextEncoding',
#  'download.pdf',
#  'print("pawan ").py',
#  'Untitled3.ipynb',
#  'Untitled.ipynb',
#  '.zshrc',
#  'python program.py',
#  '.local',
#  'Pictures',
#  'rana',
#  '.zprofile',
#  'p.html',
#  '.zsh_history',
#  'Untitled2.ipynb',
#  '.p2',
#  '.ipython',
#  'Desktop',
#  'Library',
#  'eclipse-workspace',
#  '.matplotlib',
#  'ds pyqs.pdf',
#  'Public',
#  'sss',
#  '.idlerc',
#  'fake_news_detector.ipynb',
#  'OTR-10030812574.pdf',
#  'Movies',
#  'Applications',
#  '.gradle',
#  '.Trash',
#  '.ipynb_checkpoints',
#  'kri.pdf',
#  '.jupyter',
#  'mini project',
#  'pawan.html',
#  'Documents',
#  'm4.jpeg',
#  '.vscode',
#  'Anmol wbd',
#  'Downloads',
#  '.redhat',
#  '.zsh_sessions']

# %%
import os

os.listdir("/Users/pawanrana/Desktop")
# Out:
# ['727bc38f-8434-4668-ab3f-dbc7078faf42.pdf',
#  'Screenshot 2025-11-03 at 10.26.59\u202fPM.png',
#  '.DS_Store',
#  'Screenshot 2026-08-04 at 8.16.27\u202fPM.png',
#  '-kgIpppfK_fV8P_NQgqnr2l-4-CHRH_9lp6aVyibmfiOmGGpSi9bxDfk.mp4',
#  'Qr fishing',
#  'Screenshot 2026-08-02 at 7.56.23\u202fPM.png',
#  'python',
#  '.localized',
#  'ds',
#  'Screenshot 2026-07-30 at 10.05.35\u202fAM.png',
#  'repl.py',
#  'WhatsApp Image 2025-12-29 at 17.40.04.jpeg',
#  'Screenshot 2025-12-11 at 10.49.18\u202fPM.png',
#  'java',
#  '- [x] 1. क्षितिज भाग-2 (Kshi.textClipping',
#  'Our.Fault.2025.1080p.WEB-DL.Hindi.5.1-English.5.1.ESub.x264-HDHub4u.Ms.mkv',
#  'my java',
#  'Screenshot 2026-08-14 at 2.49.38\u202fPM.png',
#  'Screenshot 2026-08-14 at 2.55.52\u202fPM.png',
#  'Photo on 23-03-25 at 12.19\u202fPM.jpg',
#  'c dss',
#  'DOC-20251006-WA0003 2.pages',
#  'Screenshot 2026-07-30 at 10.05.28\u202fAM.png',
#  'Screenshot 2025-12-11 at 10.49.11\u202fPM.png',
# ...

# %%
import glob

glob.glob("/Users/pawanrana/Desktop/*.csv")
# Out:
# ['/Users/pawanrana/Desktop/AIML Dataset.csv']

# %%
import os

for root, dirs, files in os.walk("/Users/pawanrana"):
    for file in files:
        if file.lower().endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# /Users/pawanrana/Desktop/AIML Dataset.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-log2.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-arcsinh.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-arctanh.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-sin.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-cos.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-cbrt.csv
# /Users/pawanrana/Desktop/python/.venv/lib/python3.9/site-packages/numpy/_core/tests/data/umath-validation-set-arctan.csv
# ...

# %%
df.head()

# %%
import os

for folder in ["/Users/pawanrana/Desktop", "/Users/pawanrana/Downloads"]:
    print("\n---", folder, "---")
    try:
        print(os.listdir(folder))
    except FileNotFoundError:
        print("Folder not found")
# Out:
# --- /Users/pawanrana/Desktop ---
# ...

# %%
import glob

print("Desktop:")
print(glob.glob("/Users/pawanrana/Desktop/*"))

print("\nDownloads:")
print(glob.glob("/Users/pawanrana/Downloads/*"))
# Out:
# Desktop:
# ...

# %%
df = pd.read_csv("/Users/pawanrana/Desktop/AIML Dataset.csv")

# %%
import os
os.path.exists("/Users/pawanrana/Desktop/AIML Dataset.csv")
# Out:
# True

# %%
df = pd.read_csv("/Users/pawanrana/Desktop/AIML Dataset.csv")
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 534.0 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (6362620, 11)

# %%
round(df["isFraud"].value_counts()[1] / df.shape[0] * 100,2)
# Out:
# np.float64(0.13)

# %%
import matplotlib.pyplot as plt

df["type"].value_counts().plot(kind="bar")

plt.xlabel("Transaction Type")
plt.ylabel("Count")
plt.title("Transaction Type Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
fraud_by_type = df.groupby("type")["isFraud"].mean().sort_values(ascending=True)

fraud_by_type.plot(kind="bar")

plt.xlabel("Transaction Type")
plt.ylabel("Fraud Rate")
plt.title("Fraud Rate by Transaction Type")
plt.show()

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df["amount"]), bins=100, kde=True, color="green")

plt.title("Transaction Amount Distribution (Log Scale)")
plt.xlabel("Log(Transaction Amount + 1)")
plt.ylabel("Frequency")
plt.show()

# %%
filtered_df = df[df["amount"] < 50000]

sns.boxplot(data=filtered_df, x="isFraud", y="amount")

plt.title("Transaction Amount by Fraud Status")
plt.xlabel("Fraud Status (0 = No Fraud, 1 = Fraud)")
plt.ylabel("Transaction Amount")
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["balanceDiffOrig"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["balanceDiffDest"] = df["newbalanceDest"] - df["oldbalanceDest"]

# %%
(df["balanceDiffOrig"] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDest"] < 0).sum()
# Out:
# np.int64(1238864)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0

# %%
frauds_per_step = df[df["isFraud"] == 1]["step"].value_counts().sort_index()

plt.plot(
    frauds_per_step.index,
    frauds_per_step.values,
    label="Frauds per Step"
)

plt.xlabel("Step (Time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds Over Time")
plt.grid(True)
plt.legend()
plt.show()

# %%
df.drop(columns="step", inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
 top_senders = df["nameOrig"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts().head(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df["isFraud"]==1]["nameOrig"].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER","CASH_OUT"])]

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types, x="type", hue="isFraud")
plt.title("Fraud Distribution in Transfer & Cash_Out")
plt.show()

# %%
corr = df[[
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest",
    "isFraud"
]].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
import pandas as pd

df = pd.read_csv("/Users/pawanrana/Desktop/AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"] > 0) &
    (df["newbalanceOrig"] == 0) &
    (df["type"].isin(["TRANSFER", "CASH_OUT"]))
]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.head()
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2      1  TRANSFER     181.00  C1305486145          181.0             0.0
# 3      1  CASH_OUT     181.00   C840083671          181.0             0.0
# 15     1  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19     1  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24     1  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df_model = df.drop(["nameOrig","nameDest","isFlaggedFraud"] ,axis = 1 )

# %%
df_model.head()
# Out:
#    step      type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1     1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2     1  TRANSFER    181.00          181.0            0.00             0.0
# 3     1  CASH_OUT    181.00          181.0            0.00         21182.0
# 4     1   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud
# 0             0.0        0
# 1             0.0        0
# 2             0.0        1
# 3             0.0        1
# 4             0.0        0

# %%
categorical = ["type"]

numeric = [
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest"
]

# %%
y = df_model["isFraud"]
X = df_model.drop("isFraud", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(drop="first"), categorical)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf", LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.93      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1804959,  101363],
#        [    165,    2299]])

# %%
pipeline.score(X_test,y_test) * 100
# Out:
# 94.68101714911992

# %%
import joblib

joblib.dump(pipeline, "fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/pawanrana/Desktop/AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
fraud_example = df[df["isFraud"] == 1].iloc[0]

print(fraud_example[[
    "type",
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest",
    "isFraud"
]])
# Out:
# type              TRANSFER
# amount               181.0
# oldbalanceOrg        181.0
# newbalanceOrig         0.0
# oldbalanceDest         0.0
# newbalanceDest         0.0
# isFraud                  1
# Name: 2, dtype: object

# %%
import joblib

pipeline = joblib.load("/Users/pawanrana/fraud_detection_pipeline.pkl")

# %%
test = pd.DataFrame({
    "type": [fraud_example["type"]],
    "amount": [fraud_example["amount"]],
    "oldbalanceOrg": [fraud_example["oldbalanceOrg"]],
    "newbalanceOrig": [fraud_example["newbalanceOrig"]],
    "oldbalanceDest": [fraud_example["oldbalanceDest"]],
    "newbalanceDest": [fraud_example["newbalanceDest"]]
})

print("Actual:", fraud_example["isFraud"])
print("Predicted:", pipeline.predict(test)[0])
# Out:
# Actual: 1
# Predicted: 1

# %%
print(fraud_example[[
    "type",
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest"
]])
# Out:
# type              TRANSFER
# amount               181.0
# oldbalanceOrg        181.0
# newbalanceOrig         0.0
# oldbalanceDest         0.0
# newbalanceDest         0.0
# Name: 2, dtype: object

# %%
fraud_examples = df[df["isFraud"] == 1][[
    "type",
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest"
]].head(10)

fraud_examples
# Out:
#           type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2     TRANSFER      181.00         181.00             0.0             0.0
# 3     CASH_OUT      181.00         181.00             0.0         21182.0
# 251   TRANSFER     2806.00        2806.00             0.0             0.0
# 252   CASH_OUT     2806.00        2806.00             0.0         26202.0
# 680   TRANSFER    20128.00       20128.00             0.0             0.0
# 681   CASH_OUT    20128.00       20128.00             0.0          6268.0
# 724   CASH_OUT   416001.33           0.00             0.0           102.0
# 969   TRANSFER  1277212.77     1277212.77             0.0             0.0
# 970   CASH_OUT  1277212.77     1277212.77             0.0             0.0
# 1115  TRANSFER    35063.63       35063.63             0.0             0.0
#
#       newbalanceDest
# 2               0.00
# 3               0.00
# 251             0.00
# 252             0.00
# 680             0.00
# ...

# %%
frauds = df[df["isFraud"] == 1].copy()

features = [
    "type",
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest"
]

frauds["prediction"] = pipeline.predict(frauds[features])

correct_frauds = frauds[frauds["prediction"] == 1]

correct_frauds[features].head(10)
# Out:
#           type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2     TRANSFER      181.00         181.00             0.0             0.0
# 251   TRANSFER     2806.00        2806.00             0.0             0.0
# 680   TRANSFER    20128.00       20128.00             0.0             0.0
# 969   TRANSFER  1277212.77     1277212.77             0.0             0.0
# 970   CASH_OUT  1277212.77     1277212.77             0.0             0.0
# 1115  TRANSFER    35063.63       35063.63             0.0             0.0
# 1116  CASH_OUT    35063.63       35063.63             0.0         31140.0
# 1869  TRANSFER    25071.46       25071.46             0.0             0.0
# 2301  TRANSFER   235238.66      235238.66             0.0             0.0
# 2302  CASH_OUT   235238.66      235238.66             0.0             0.0
#
#       newbalanceDest
# 2               0.00
# 251             0.00
# 680             0.00
# 969             0.00
# 970       2444985.19
# ...

# %%
probability = model.predict_proba(data)[0][1]
prediction = model.predict(data)[0]

print("Prediction:", prediction)
print(f"Fraud Probability: {probability * 100:.2f}%")
# Out:
# Prediction: 1
# Fraud Probability: 75.83%

# %%
import joblib

model = joblib.load("/Users/pawanrana/fraud_detection_pipeline.pkl")

# %%
data = pd.DataFrame({
    "type": ["TRANSFER"],
    "amount": [181],
    "oldbalanceOrg": [181],
    "newbalanceOrig": [0],
    "oldbalanceDest": [0],
    "newbalanceDest": [0]
})

# %%
probability = model.predict_proba(data)[0][1]

print(f"Fraud Probability: {probability * 100:.2f}%")
# Out:
# Fraud Probability: 75.83%

# %%
prediction = model.predict(data)

# %%
probability = model.predict_proba(data)[0][1]

print(f"Fraud Probability: {probability * 100:.2f}%")
# Out:
# Fraud Probability: 75.83%

# %%
prediction = model.predict(data)[0]

print("Prediction:", prediction)
print(f"Fraud Probability: {probability * 100:.2f}%")
# Out:
# Prediction: 1
# Fraud Probability: 75.83%
